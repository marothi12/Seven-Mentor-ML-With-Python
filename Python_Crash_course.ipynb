# %% [markdown]
# ## Python Crash Course ##

# %%
1
# Out:
# 1

# %%
1
# Out:
# 1

# %%
1.0
# Out:
# 1.0

# %%
type(1)
# Out:
# int

# %%
type(1.0)
# Out:
# float

# %%
1+3
# Out:
# 4

# %%
1/2
# Out:
# 0.5

# %%
2**4
# Out:
# 16

# %%
4%2
# Out:
# 0

# %%
5 % 2
# Out:
# 1

# %%
2 + 3 * 5 + 5
# Out:
# 22

# %%
(2 + 3) * (5+5)
# Out:
# 50

# %%
name_of_var = 2

# %%
x = 1
y = 2

# %%
'string'
# Out:
# 'string'

# %%
'double'
# Out:
# 'double'

# %%
"I do n't like that"
# Out:
# "I do n't like that"

# %%
print("Hello")
# Out:
# Hello

# %%
"hello"
# Out:
# 'hello'

# %%
print("My name is {}".format('Joe'))
# Out:
# My name is Joe

# %%
print("My name is {},my number is {}".format('Joe','10'))
# Out:
# My name is Joe,my number is 10

# %%
print("First:{x} Second {y}".format(x='xxx',y='yyy'))
# Out:
# First:xxx Second yyy

# %%
print("First:{y} Second {x}".format(x='xxx',y='yyy'))
# Out:
# First:yyy Second xxx

# %%
[1,2,3,]
# Out:
# [1, 2, 3]

# %%
['a','b','c']
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# ## Array or List ##

# %%
my_list = ['a','b','c']

# %%
my_list
# Out:
# ['a', 'b', 'c']

# %%
my_list[0]
# Out:
# 'a'

# %%
my_list[2]
# Out:
# 'c'

# %%
my_list[-1]
# Out:
# 'c'

# %%
my_list[0] = "New"

# %%
my_list
# Out:
# ['New', 'b', 'c']

# %%
my_list
# Out:
# ['New', 'b', 'c']

# %%
my_list.append('d')

# %%
my_list
# Out:
# ['New', 'b', 'c', 'd', 'd']

# %%
my_list = [1,2,[100,200]]

# %%
my_list
# Out:
# [1, 2, [100, 200]]

# %%
my_list[2]
# Out:
# [100, 200]

# %%
my_list[2][1]
# Out:
# 200

# %% [markdown]
# ## Dictionary or HashTable ##

# %%
d = {'key':'value1','key2':'value2'}

# %%
d
# Out:
# {'key': 'value1', 'key2': 'value2'}

# %%
d['key2']
# Out:
# 'value2'

# %%
print(d)
# Out:
# {'key': 'value1', 'key2': 'value2'}

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
1
# Out:
# 1

# %% [markdown]
# ## Tuple ##

# %% [markdown]
# * Tuples are immutable

# %%
t = (1,2,3)

# %%
t[0] = 'New'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 t[0] = 'New'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Set ##

# %% [markdown]
# * set is undered collection of elemdents with no ducplicate
