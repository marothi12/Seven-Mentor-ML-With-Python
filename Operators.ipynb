# %% [markdown]
# ## Opertors in python ##

# %% [markdown]
# * comparsion Operator *
# *1. <
#
# * 2.>
#
# * 3.=
#
# * 4.==
#
# * 5.!==

# %%
1==1
# Out:
# True

# %%
'a'=='A'
# Out:
# False

# %%
1 !=2
# Out:
# True

# %%
(1==1)and('a'=='a')
# Out:
# True

# %%
1==2 and 'a'=='a'
# Out:
# False

# %%
(1==2)or('a'=='a')
# Out:
# True

# %% [markdown]
# ## If ##

# %%
if 1==2:
    print('yes1')

# %% [markdown]
# ##  IF,Elif ##

# %%
if 1==2:
    print('worded')
elif 3==3:
    print('second cond true')
else:
    print('npoe')
# Out:
# second cond true

# %% [markdown]
# ## for ##

# %%
seq = [1,2,3,4,5]

# %%
for item in seq:
    print(seq)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]

# %%
for element in seq:
    print(element+element)
# Out:
# 2
# 4
# 6

# %% [markdown]
# ## while ##

# %%
i = 1
while i < 5:
    print('i is {}'.format(i))
    i = i+1
# Out:
# i is 1
# i is 2
# i is 3
# i is 4

# %% [markdown]
# ## Range ##

# %%
range(7)
# Out:
# range(0, 7)

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(2,5))
# Out:
# [2, 3, 4]

# %%
for x in range(5):
    print('hi')
# Out:
# hi
# hi
# hi
# hi
# hi

# %%
x = [1,2,3,4,5]

# %%
out = []
for num in x:
    out.append(num**2)
print(out)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## List Comphresion ##

# %%
[num**2  for num in x]
# Out:
# [1, 4, 9, 16, 25]
