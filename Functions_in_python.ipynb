# %% [markdown]
# ## Function ##

# %%
def my_func():
    print('Hello')

# %%
my_func()
# Out:
# Hello

# %%
def my_func(name):
    print('hello'+name)

# %%
my_func('Marothi')
# Out:
# helloMarothi

# %%
def square(x):
    return x**2

# %%
result = square(2)

# %%
result
# Out:
# 4

# %%
type(result)
# Out:
# int

# %%
def times_two(var):
    return var*2

# %%
times_two(10)
# Out:
# 20

# %%
lambda var: var2
# Out:
# <function __main__.<lambda>(var)>

# %%
lambda var: var*2
# Out:
# <function __main__.<lambda>(var)>

# %%
st = 'Hello my name is Ram'

# %%
st.upper()
# Out:
# 'HELLO MY NAME IS RAM'

# %%
st.split()
# Out:
# ['Hello', 'my', 'name', 'is', 'Ram']

# %%
tweet = 'Hello #sports'

# %%
tweet.split('#')
# Out:
# ['Hello ', 'sports']

# %%
tweet.split('#')[-1]
# Out:
# 'sports'

# %%
d =
